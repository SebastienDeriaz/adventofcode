# %%
import numpy as np
from math import comb, perm
import matplotlib.pyplot as plt

# %%
print(M)

plt.imshow(M)
plt.show()
# Out:
# [[2 1 1 ... 2 2 3]
#  [2 1 2 ... 3 1 3]
#  [3 1 2 ... 1 3 3]
#  ...
#  [2 1 2 ... 3 1 1]
#  [3 3 2 ... 3 2 2]
#  [3 2 3 ... 3 2 3]]
